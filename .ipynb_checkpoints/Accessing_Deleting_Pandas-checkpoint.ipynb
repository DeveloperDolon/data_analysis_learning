# %%
import pandas as pd

# %%
gro = pd.Series(data=[30, 6, "Yes", "No"], index=["eggs", "apples", "milk", "bread"])
gro
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object
